# %%
# Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## both platforms
# - overall dates
# - pre covid
# - post covid
# ## box office
# - overall dates
# - pre covid
# - post covid
# ## netflix
# - overall dates
# - pre covid
# - post covid

# %%
df = pd.read_csv("../output_data/clean_data_for_analysis.csv")

# dropped incorrect currency data
df = df.loc[df['imdbID']!='tt10579952',:]
df
# Out:
#                                              Title   Type     Release  \
# 0                          Insidious: The Last Key  Movie  2018-01-05
# 1                                         Stratton  Movie  2018-01-05
# 2                                    Sweet Country  Movie  2018-04-06
# 3                                     The Commuter  Movie  2018-01-12
# 4                                       Freak Show  Movie  2018-01-12
# ...                                            ...    ...         ...
# 1148                      Avatar: The Way of Water  Movie  2022-12-16
# 1149                  Puss in Boots: The Last Wish  Movie  2022-12-21
# 1150                                       Wildcat  Movie  2022-12-30
# 1151                                       Babylon  Movie  2022-12-23
# 1152  Whitney Houston: I Wanna Dance with Somebody  Movie  2022-12-23
#
#       Runtime        Genre  Nominations  Metascore  imdbRating  imdbVotes  \
# 0      6180.0       Horror          NaN       49.0         5.7      63102
# 1      5700.0       Action          NaN       26.0         4.8       5405
# 2      6780.0    Adventure          NaN       88.0         6.9       8855
# 3      6240.0       Action          NaN       56.0         6.3     118954
# 4      5460.0       Comedy          NaN       54.0         6.5       4376
# ...       ...          ...          ...        ...         ...        ...
# 1148  11520.0       Action          3.0       67.0         7.7     355332
# 1149   6120.0    Animation          1.0       73.0         7.9     117294
# 1150   6360.0  Documentary          NaN       71.0         7.8       2605
# 1151  11340.0       Comedy          3.0       60.0         7.2     107214
# 1152   8640.0    Biography          NaN       51.0         6.6      13210
#
#           imdbID       Budget         Gross Platform
# 0      tt5726086   10000000.0  1.678856e+08   others
# 1      tt3567666          NaN  2.572120e+05   others
# 2      tt6958212          NaN  1.849718e+06   others
# 3      tt1590193   30000000.0  1.199424e+08   others
# 4      tt5089534          NaN  2.065700e+04   others
# ...          ...          ...           ...      ...
# 1148   tt1630029  350000000.0  2.315057e+09   others
# 1149   tt3915174   90000000.0  4.800034e+08   others
# 1150  tt13622204          NaN           NaN   others
# 1151  tt10640346   78000000.0  6.337762e+07   others
# 1152  tt12193804   45000000.0  5.670808e+07   others
#
# [1152 rows x 13 columns]

# %%
budget_df = df[['Title','Platform','Budget','imdbRating','Metascore','imdbVotes','Release']].dropna()
budget_df
# Out:
#                                              Title Platform       Budget  \
# 0                          Insidious: The Last Key   others   10000000.0
# 3                                     The Commuter   others   30000000.0
# 7                                        12 Strong   others   35000000.0
# 8                                   Den of Thieves   others   30000000.0
# 9                                  Forever My Girl   others    3500000.0
# ...                                            ...      ...          ...
# 1144                                     The Whale   others   10000000.0
# 1148                      Avatar: The Way of Water   others  350000000.0
# 1149                  Puss in Boots: The Last Wish   others   90000000.0
# 1151                                       Babylon   others   78000000.0
# 1152  Whitney Houston: I Wanna Dance with Somebody   others   45000000.0
#
#       imdbRating  Metascore  imdbVotes     Release
# 0            5.7       49.0      63102  2018-01-05
# 3            6.3       56.0     118954  2018-01-12
# 7            6.5       54.0      85233  2018-01-19
# 8            7.0       49.0     116702  2018-01-19
# 9            6.6       36.0      18766  2018-01-19
# ...          ...        ...        ...         ...
# 1144         7.7       60.0     127099  2022-12-21
# 1148         7.7       67.0     355332  2022-12-16
# 1149         7.9       73.0     117294  2022-12-21
# 1151         7.2       60.0     107214  2022-12-23
# 1152         6.6       51.0      13210  2022-12-23
#
# [485 rows x 7 columns]

# %% [markdown]
# # Overall Comparisons 2018-2022

# %%
x_axis = budget_df['Budget']

data = budget_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Overall Budget vs. IMDB Rating")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = budget_df['Budget']

data = budget_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Overall Budget vs. IMDB Votes")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDB Votes (millions)")
plt.show()

# %%
x_axis = budget_df['Budget']

data = budget_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Overall Budget vs. Metascore")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()

# %% [markdown]
# # Overall Pre Covid Comparisons

# %%
# pre covid movies
budget_df['Release'] = pd.to_datetime(budget_df['Release'])
budget_df.sort_values(by='Release')

pre_start = '2018-01-01'
pre_end = '2019-12-31'

pre_df = budget_df[(budget_df['Release'] > pre_start) & (budget_df['Release']< pre_end)]
pre_df
# Out:
#                        Title Platform       Budget  imdbRating  Metascore  \
# 0    Insidious: The Last Key   others   10000000.0         5.7       49.0
# 3               The Commuter   others   30000000.0         6.3       56.0
# 7                  12 Strong   others   35000000.0         6.5       54.0
# 8             Den of Thieves   others   30000000.0         7.0       49.0
# 9            Forever My Girl   others    3500000.0         6.6       36.0
# ..                       ...      ...          ...         ...        ...
# 403                     Cats   others   95000000.0         2.8       32.0
# 404        Spies in Disguise   others  100000000.0         6.8       54.0
# 405             Little Women   others   40000000.0         7.8       91.0
# 575             The Informer   others   60000000.0         6.6       61.0
# 754              How It Ends  netflix   20000000.0         5.0       36.0
#
#      imdbVotes    Release
# 0        63102 2018-01-05
# 3       118954 2018-01-12
# 7        85233 2018-01-19
# 8       116702 2018-01-19
# 9        18766 2018-01-19
# ..         ...        ...
# 403      53048 2019-12-20
# 404      52021 2019-12-25
# 405     216502 2019-12-25
# 575      39263 2019-08-30
# 754      55229 2018-07-13
#
# [254 rows x 7 columns]

# %%
# plotting

x_axis = pre_df['Budget']

data = pre_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Budget vs. IMDB Rating Pre-Covid")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = pre_df['Budget']

data = pre_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Budget vs. IMDB Votes Pre-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDB Votes (millions)")
plt.show()

# %%
x_axis = pre_df['Budget']

data = pre_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Budget vs. Metascore Pre Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()

# %% [markdown]
# # Overall Post Covid Comparisons

# %%
# post covid movies
post_start = '2020-01-01'
post_end = '2022-12-31'

post_df = budget_df[(budget_df['Release'] > post_start) & (budget_df['Release']< post_end)]
post_df
# Out:
#                                              Title Platform       Budget  \
# 406                                           1917   others   95000000.0
# 407                                     Just Mercy   others   25000000.0
# 409                                     Underwater   others   80000000.0
# 413                              Bad Boys for Life   others   90000000.0
# 414                                       Dolittle   others  175000000.0
# ...                                            ...      ...          ...
# 1144                                     The Whale   others   10000000.0
# 1148                      Avatar: The Way of Water   others  350000000.0
# 1149                  Puss in Boots: The Last Wish   others   90000000.0
# 1151                                       Babylon   others   78000000.0
# 1152  Whitney Houston: I Wanna Dance with Somebody   others   45000000.0
#
#       imdbRating  Metascore  imdbVotes    Release
# 406          8.2       78.0     613994 2020-01-10
# 407          7.6       68.0      70926 2020-01-10
# 409          5.8       48.0      87056 2020-01-10
# 413          6.5       59.0     165725 2020-01-17
# 414          5.6       26.0      66861 2020-01-17
# ...          ...        ...        ...        ...
# 1144         7.7       60.0     127099 2022-12-21
# 1148         7.7       67.0     355332 2022-12-16
# 1149         7.9       73.0     117294 2022-12-21
# 1151         7.2       60.0     107214 2022-12-23
# 1152         6.6       51.0      13210 2022-12-23
#
# [231 rows x 7 columns]

# %%
#plotting

x_axis = post_df['Budget']

data = post_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Budget vs. IMDB Rating Post-Covid")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = post_df['Budget']

data = post_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Budget vs. IMDB Votes Post-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDB Votes")
plt.show()

# %%
x_axis = post_df['Budget']

data = post_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Budget vs. Metascore Post-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()

# %% [markdown]
# # Box Office Overall Comparisons

# %%
box_df = budget_df[budget_df['Platform']=='others']
box_df
# Out:
#                                              Title Platform       Budget  \
# 0                          Insidious: The Last Key   others   10000000.0
# 3                                     The Commuter   others   30000000.0
# 7                                        12 Strong   others   35000000.0
# 8                                   Den of Thieves   others   30000000.0
# 9                                  Forever My Girl   others    3500000.0
# ...                                            ...      ...          ...
# 1144                                     The Whale   others   10000000.0
# 1148                      Avatar: The Way of Water   others  350000000.0
# 1149                  Puss in Boots: The Last Wish   others   90000000.0
# 1151                                       Babylon   others   78000000.0
# 1152  Whitney Houston: I Wanna Dance with Somebody   others   45000000.0
#
#       imdbRating  Metascore  imdbVotes    Release
# 0            5.7       49.0      63102 2018-01-05
# 3            6.3       56.0     118954 2018-01-12
# 7            6.5       54.0      85233 2018-01-19
# 8            7.0       49.0     116702 2018-01-19
# 9            6.6       36.0      18766 2018-01-19
# ...          ...        ...        ...        ...
# 1144         7.7       60.0     127099 2022-12-21
# 1148         7.7       67.0     355332 2022-12-16
# 1149         7.9       73.0     117294 2022-12-21
# 1151         7.2       60.0     107214 2022-12-23
# 1152         6.6       51.0      13210 2022-12-23
#
# [442 rows x 7 columns]

# %%
x_axis = box_df['Budget']

data = box_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Overall Box Office Budget vs. IMDB Rating")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = box_df['Budget']

data = box_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Overall Box Office Budget vs. IMDB Votes")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDB Votes (millions)")
plt.show()

# %%
x_axis = box_df['Budget']

data = box_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Overall Box Office Budget vs. Metascore")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()

# %% [markdown]
# # Box Office Pre Covid Comparisons

# %%
box_pre_df = box_df[(box_df['Release'] > pre_start) & (box_df['Release']< pre_end)]
box_pre_df
# Out:
#                        Title Platform       Budget  imdbRating  Metascore  \
# 0    Insidious: The Last Key   others   10000000.0         5.7       49.0
# 3               The Commuter   others   30000000.0         6.3       56.0
# 7                  12 Strong   others   35000000.0         6.5       54.0
# 8             Den of Thieves   others   30000000.0         7.0       49.0
# 9            Forever My Girl   others    3500000.0         6.6       36.0
# ..                       ...      ...          ...         ...        ...
# 400               Uncut Gems   others   19000000.0         7.4       91.0
# 403                     Cats   others   95000000.0         2.8       32.0
# 404        Spies in Disguise   others  100000000.0         6.8       54.0
# 405             Little Women   others   40000000.0         7.8       91.0
# 575             The Informer   others   60000000.0         6.6       61.0
#
#      imdbVotes    Release
# 0        63102 2018-01-05
# 3       118954 2018-01-12
# 7        85233 2018-01-19
# 8       116702 2018-01-19
# 9        18766 2018-01-19
# ..         ...        ...
# 400     293738 2019-12-25
# 403      53048 2019-12-20
# 404      52021 2019-12-25
# 405     216502 2019-12-25
# 575      39263 2019-08-30
#
# [243 rows x 7 columns]

# %%
#plotting

x_axis = box_pre_df['Budget']

data = box_pre_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Box Office Budget vs. IMDB Rating Pre-Covid")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = box_pre_df['Budget']

data = box_pre_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Box Office Budget vs. IMDB Votes Pre-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDB Votes (millions)")
plt.show()

# %%
x_axis = box_pre_df['Budget']

data = box_pre_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Box Office Budget vs. Metascore Pre-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()

# %% [markdown]
# # Box Office Post Covid Comparisons

# %%
box_post_df = box_df[(box_df['Release'] > post_start) & (box_df['Release']< post_end)]
box_post_df.head()
# Out:
#                  Title Platform       Budget  imdbRating  Metascore  \
# 406               1917   others   95000000.0         8.2       78.0
# 407         Just Mercy   others   25000000.0         7.6       68.0
# 409         Underwater   others   80000000.0         5.8       48.0
# 413  Bad Boys for Life   others   90000000.0         6.5       59.0
# 414           Dolittle   others  175000000.0         5.6       26.0
#
#      imdbVotes    Release
# 406     613994 2020-01-10
# 407      70926 2020-01-10
# 409      87056 2020-01-10
# 413     165725 2020-01-17
# 414      66861 2020-01-17

# %%
x_axis = box_post_df['Budget']

data = box_post_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Box Office Budget vs. IMDB Rating Post-Covid")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = box_post_df['Budget']

data = box_post_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Box Office Budget vs. IMDB Votes Post-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDB Votes")
plt.show()

# %%
x_axis = box_post_df['Budget']

data = box_post_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Box Office Budget vs. Metascore Post-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()

# %% [markdown]
# # Netflix Overall Comparisons

# %%
netflix_df = budget_df[budget_df['Platform']=='netflix']
netflix_df.head()
# Out:
#                        Title Platform       Budget  imdbRating  Metascore  \
# 16   The Cloverfield Paradox  netflix   45000000.0         5.5       37.0
# 235         High Flying Bird  netflix    2000000.0         6.2       78.0
# 242          Triple Frontier  netflix  115000000.0         6.4       61.0
# 247           The Highwaymen  netflix   49000000.0         6.9       58.0
# 269            Someone Great  netflix    5000000.0         6.1       63.0
#
#      imdbVotes    Release
# 16      108263 2018-02-04
# 235       8958 2019-02-08
# 242     134669 2019-03-13
# 247      95263 2019-03-29
# 269      23719 2019-04-19

# %%
x_axis = netflix_df['Budget']

data = netflix_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Netflix Budget vs. IMDB Rating")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = netflix_df['Budget']

data = netflix_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Box Office Budget vs. IMDB Votes")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDB Votes")
plt.show()

# %%
x_axis = netflix_df['Budget']

data = netflix_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Box Office Budget vs. Metascore")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()

# %% [markdown]
# # Netflix Comparisons Pre Covid

# %%
net_pre_df = netflix_df[(netflix_df['Release'] > pre_start) & (netflix_df['Release']< pre_end)]
net_pre_df
# Out:
#                                Title Platform       Budget  imdbRating  \
# 16           The Cloverfield Paradox  netflix   45000000.0         5.5
# 235                 High Flying Bird  netflix    2000000.0         6.2
# 242                  Triple Frontier  netflix  115000000.0         6.4
# 247                   The Highwaymen  netflix   49000000.0         6.9
# 269                    Someone Great  netflix    5000000.0         6.1
# 358  El Camino: A Breaking Bad Movie  netflix    6000000.0         7.3
# 370                     The Irishman  netflix  159000000.0         7.8
# 373                   Marriage Story  netflix   18600000.0         7.9
# 379                            Klaus  netflix   40000000.0         8.2
# 398                    6 Underground  netflix  150000000.0         6.1
# 754                      How It Ends  netflix   20000000.0         5.0
#
#      Metascore  imdbVotes    Release
# 16        37.0     108263 2018-02-04
# 235       78.0       8958 2019-02-08
# 242       61.0     134669 2019-03-13
# 247       58.0      95263 2019-03-29
# 269       63.0      23719 2019-04-19
# 358       72.0     263522 2019-10-11
# 370       94.0     400341 2019-11-27
# 373       94.0     321944 2019-12-06
# 379       65.0     164553 2019-11-15
# 398       41.0     183660 2019-12-13
# 754       36.0      55229 2018-07-13

# %%
x_axis = net_pre_df['Budget']

data = net_pre_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Netflix Budget vs. IMDB Rating Pre-Covid")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = net_pre_df['Budget']

data = net_pre_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Netflix Budget vs. IMDB Votes Pre-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDB Votes")
plt.show()

# %%
x_axis = net_pre_df['Budget']

data = net_pre_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Netflix Budget vs. Metascore Pre-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()

# %% [markdown]
# # Netflix Comparisons Post Covid

# %%
net_post_df = netflix_df[(netflix_df['Release'] > post_start) & (netflix_df['Release']< post_end)]
net_post_df.head()
# Out:
#                           Title Platform      Budget  imdbRating  Metascore  \
# 457                      Sergio  netflix  16000000.0         6.2       55.0
# 459                  Extraction  netflix  65000000.0         6.7       56.0
# 490               The Old Guard  netflix  70000000.0         6.6       70.0
# 501               Project Power  netflix  85000000.0         6.0       51.0
# 532  The Trial of the Chicago 7  netflix  35000000.0         7.7       76.0
#
#      imdbVotes    Release
# 457      10361 2020-04-17
# 459     211387 2020-04-24
# 490     171334 2020-07-10
# 501      92334 2020-08-14
# 532     182715 2020-10-16

# %%
x_axis = net_post_df['Budget']

data = net_post_df['imdbRating']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Netflix Budget vs. IMDB Rating Post-Covid")
plt.xlabel("Budget")
plt.ylabel('IMDB Rating')
plt.show()

# %%
x_axis = net_post_df['Budget']

data = net_post_df['imdbVotes']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Netflix Budget vs. IMDB Votes Post-Covid")
plt.xlabel("Budget")
plt.ylabel("IMDB Votes")
plt.show()

# %%
x_axis = net_post_df['Budget']

data = net_post_df['Metascore']

plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", alpha=0.75)

m, b = np.polyfit(x_axis, data, 1)
plt.plot(x_axis, m*x_axis+b)

plt.title("Netflix Budget vs. Metascore Post-Covid")
plt.xlabel("Budget (millions)")
plt.ylabel("Metascore")
plt.show()
